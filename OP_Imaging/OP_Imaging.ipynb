# %%
import pandas as pd
import openpyxl
from pathlib import Path

raw_national_df = pd.read_csv("Resources\Outpatient_Imaging_Efficiency-National.csv")
raw_state_df = pd.read_csv("Resources\Outpatient_Imaging_Efficiency-State.csv")

raw_df = pd.merge(raw_state_df, raw_national_df, how="left", on=["Measure ID", "Measure ID"])

raw_df.head()
# Out:
#   State Measure ID                                     Measure Name_x Score_x  \
# 0    AK      OP_10                Abdomen CT Use of Contrast Material       5
# 1    AK      OP_13  Outpatients who got cardiac imaging stress tes...     3.9
# 2    AK      OP_39               Breast Cancer Screening Recall Rates     7.5
# 3    AK       OP_8                 MRI Lumbar Spine for Low Back Pain    43.2
# 4    AL      OP_10                Abdomen CT Use of Contrast Material       9
#
#    Footnote_x Start Date_x  End Date_x  \
# 0         NaN   07/01/2021  06/30/2022
# 1         NaN   07/01/2021  06/30/2022
# 2         NaN   07/01/2021  06/30/2022
# 3         NaN   07/01/2021  06/30/2022
# 4         NaN   07/01/2021  06/30/2022
#
#                                       Measure Name_y  Score_y  Footnote_y  \
# 0                Abdomen CT Use of Contrast Material      6.0         NaN
# 1  Outpatients who got cardiac imaging stress tes...      3.8         NaN
# 2               Breast Cancer Screening Recall Rates      9.2         NaN
# 3                 MRI Lumbar Spine for Low Back Pain     37.1         NaN
# 4                Abdomen CT Use of Contrast Material      6.0         NaN
#
#   Start Date_y  End Date_y
# 0   07/01/2021  06/30/2022
# 1   07/01/2021  06/30/2022
# 2   07/01/2021  06/30/2022
# 3   07/01/2021  06/30/2022
# 4   07/01/2021  06/30/2022

# %%
raw_df = raw_df[["State", "Measure ID", "Measure Name_x", "Score_x", "Score_y", "Start Date_x", "End Date_x"]]
raw_df.head()
# Out:
#   State Measure ID                                     Measure Name_x Score_x  \
# 0    AK      OP_10                Abdomen CT Use of Contrast Material       5
# 1    AK      OP_13  Outpatients who got cardiac imaging stress tes...     3.9
# 2    AK      OP_39               Breast Cancer Screening Recall Rates     7.5
# 3    AK       OP_8                 MRI Lumbar Spine for Low Back Pain    43.2
# 4    AL      OP_10                Abdomen CT Use of Contrast Material       9
#
#    Score_y Start Date_x  End Date_x
# 0      6.0   07/01/2021  06/30/2022
# 1      3.8   07/01/2021  06/30/2022
# 2      9.2   07/01/2021  06/30/2022
# 3     37.1   07/01/2021  06/30/2022
# 4      6.0   07/01/2021  06/30/2022

# %%
op_df = raw_df.rename(columns={"Measure ID": "Test Code", "Measure Name_x" : "Test Reason", "Score_x": "State Score",
                                "Score_y": "National Score", "Start Date_x": "Start Date", "End Date_x": "End Date"})
op_df.head()
# Out:
#   State Test Code                                        Test Reason  \
# 0    AK     OP_10                Abdomen CT Use of Contrast Material
# 1    AK     OP_13  Outpatients who got cardiac imaging stress tes...
# 2    AK     OP_39               Breast Cancer Screening Recall Rates
# 3    AK      OP_8                 MRI Lumbar Spine for Low Back Pain
# 4    AL     OP_10                Abdomen CT Use of Contrast Material
#
#   State Score  National Score  Start Date    End Date
# 0           5             6.0  07/01/2021  06/30/2022
# 1         3.9             3.8  07/01/2021  06/30/2022
# 2         7.5             9.2  07/01/2021  06/30/2022
# 3        43.2            37.1  07/01/2021  06/30/2022
# 4           9             6.0  07/01/2021  06/30/2022

# %%
cleaned_op_df = op_df[(op_df["State Score"] != "Not Available")][["State", "Test Code", "Test Reason", "State Score",
                                                                   "National Score", "Start Date", "End Date"]]
cleaned_op_df.head()
# Out:
#   State Test Code                                        Test Reason  \
# 0    AK     OP_10                Abdomen CT Use of Contrast Material
# 1    AK     OP_13  Outpatients who got cardiac imaging stress tes...
# 2    AK     OP_39               Breast Cancer Screening Recall Rates
# 3    AK      OP_8                 MRI Lumbar Spine for Low Back Pain
# 4    AL     OP_10                Abdomen CT Use of Contrast Material
#
#   State Score  National Score  Start Date    End Date
# 0           5             6.0  07/01/2021  06/30/2022
# 1         3.9             3.8  07/01/2021  06/30/2022
# 2         7.5             9.2  07/01/2021  06/30/2022
# 3        43.2            37.1  07/01/2021  06/30/2022
# 4           9             6.0  07/01/2021  06/30/2022

# %%
cleaned_op_df = cleaned_op_df.astype({"State Score": float}, errors='raise')
cleaned_op_df.dtypes
# Out:
# State              object
# Test Code          object
# Test Reason        object
# State Score       float64
# National Score    float64
# Start Date         object
# End Date           object
# dtype: object

# %%
national_avg_df = cleaned_op_df.groupby("State")["National Score"].mean()
state_avg_df = cleaned_op_df.groupby("State")["State Score"].mean()
print(national_avg_df.head())
print(state_avg_df.head())
# Out:
# State
# AK    14.025
# AL    14.025
# AR    14.025
# AZ    14.025
# CA    14.025
# Name: National Score, dtype: float64
# State
# AK    14.900
# AL    15.150
# AR    14.700
# AZ    13.175
# CA    14.375
# Name: State Score, dtype: float64

# %%
average_scores = pd.DataFrame({"State Average": state_avg_df, "National Average": national_avg_df})
average_scores.head()
# Out:
#        State Average  National Average
# State
# AK            14.900            14.025
# AL            15.150            14.025
# AR            14.700            14.025
# AZ            13.175            14.025
# CA            14.375            14.025

# %%
inefficent_states = average_scores[(average_scores["State Average"] > average_scores["National Average"])]
inefficent_states["Verdict"] = "Inefficient"
inefficent_states.head()
# Out:
# C:\Users\100676677\AppData\Local\Temp\ipykernel_17000\4051800990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inefficent_states["Verdict"] = "Inefficient"
#        State Average  National Average      Verdict
# State
# AK            14.900            14.025  Inefficient
# AL            15.150            14.025  Inefficient
# AR            14.700            14.025  Inefficient
# CA            14.375            14.025  Inefficient
# CO            14.300            14.025  Inefficient

# %%
efficent_states = average_scores[(average_scores["State Average"] < average_scores["National Average"])]
efficent_states["Verdict"] = "Efficient"
efficent_states.head()
# Out:
# C:\Users\100676677\AppData\Local\Temp\ipykernel_17000\4210703357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   efficent_states["Verdict"] = "Efficient"
#        State Average  National Average    Verdict
# State
# AZ            13.175            14.025  Efficient
# DC            12.550            14.025  Efficient
# DE            11.150            14.025  Efficient
# GA            13.500            14.025  Efficient
# HI            11.575            14.025  Efficient

# %%
verdict_df = pd.concat([inefficent_states, efficent_states])
verdict_df = verdict_df.sort_values(by = "State", ascending=True)
verdict_df
# Out:
#        State Average  National Average      Verdict
# State
# AK            14.900            14.025  Inefficient
# AL            15.150            14.025  Inefficient
# AR            14.700            14.025  Inefficient
# AZ            13.175            14.025    Efficient
# CA            14.375            14.025  Inefficient
# CO            14.300            14.025  Inefficient
# CT            17.500            14.025  Inefficient
# DC            12.550            14.025    Efficient
# DE            11.150            14.025    Efficient
# FL            14.450            14.025  Inefficient
# GA            13.500            14.025    Efficient
# HI            11.575            14.025    Efficient
# IA            12.175            14.025    Efficient
# ID            13.850            14.025    Efficient
# IL            14.350            14.025  Inefficient
# IN            13.475            14.025    Efficient
# KS            13.925            14.025    Efficient
# KY            12.950            14.025    Efficient
# LA            15.400            14.025  Inefficient
# MA            12.975            14.025    Efficient
# MD            13.575            14.025    Efficient
# ME            13.375            14.025    Efficient
# MI            13.700            14.025    Efficient
# MN            13.900            14.025    Efficient
# MO            13.725            14.025    Efficient
# MS            14.425            14.025  Inefficient
# MT            14.925            14.025  Inefficient
# NC            12.750            14.025    Efficient
# ND            12.925            14.025    Efficient
# NE            13.175            14.025    Efficient
# NH            13.325            14.025    Efficient
# NJ            15.725            14.025  Inefficient
# NM            14.975            14.025  Inefficient
# NV            13.825            14.025    Efficient
# NY            19.075            14.025  Inefficient
# OH            12.875            14.025    Efficient
# OK            14.475            14.025  Inefficient
# OR            14.675            14.025  Inefficient
# PA            13.200            14.025    Efficient
# PR            28.225            14.025  Inefficient
# RI            13.575            14.025    Efficient
# SC            13.375            14.025    Efficient
# SD            12.300            14.025    Efficient
# TN            13.000            14.025    Efficient
# TX            14.925            14.025  Inefficient
# UT            14.800            14.025  Inefficient
# VA            12.675            14.025    Efficient
# VT            12.250            14.025    Efficient
# WA            13.025            14.025    Efficient
# WI            13.075            14.025    Efficient
# WV            14.425            14.025  Inefficient
# WY            14.950            14.025  Inefficient
